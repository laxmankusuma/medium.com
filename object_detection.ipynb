# %%
pip install cvlib
# Out:
# Collecting cvlib
#   Downloading cvlib-0.2.6.tar.gz (10.0 MB)
#      |████████████████████████████████| 10.0 MB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from cvlib) (1.19.5)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from cvlib) (2.25.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.7/site-packages (from cvlib) (7.2.0)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from cvlib) (2.9.0)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->cvlib) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->cvlib) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->cvlib) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->cvlib) (2.10)
# Building wheels for collected packages: cvlib, imutils, progressbar
#   Building wheel for cvlib (setup.py) ... done
#   Created wheel for cvlib: filename=cvlib-0.2.6-py3-none-any.whl size=10044621 sha256=7b51b33e560a18df3152ff01ad70977d76fc103921a0279b93c12efcc42b1c13
#   Stored in directory: /root/.cache/pip/wheels/9b/96/9b/373c07517ffe0bedbebc0813aec1e62cb2bb1dee91b3694895
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25860 sha256=cf63a6ab4423989ab06a5868d6dee0dc14046e1889e8aa032eafa41981806b55
#   Stored in directory: /root/.cache/pip/wheels/86/d7/0a/4923351ed1cec5d5e24c1eaf8905567b02a0343b24aa873df2
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12075 sha256=4bbee5a7e54d138d10c3ff0816cbbe8a84c2b5536ff79663754773211db05d7c
#   Stored in directory: /root/.cache/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
# Successfully built cvlib imutils progressbar
# Installing collected packages: progressbar, imutils, cvlib
# Successfully installed cvlib-0.2.6 imutils-0.5.4 progressbar-2.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Ref :
#
# https://medium.com/coders-camp/230-machine-learning-projects-with-python-5d0c7abf8265

# %%
# import required libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

# %%
# read image
image = cv2.imread("../input/cars-on-road/cars.jpg")

#It will return the bounding box co-ordinates, corrensponding labels and confidence scores for the detected objects in the image.
box, label, count = cv.detect_common_objects(image)

output = draw_bbox(image, box, label, count)
plt.imshow(output)
plt.show()
print("Number of cars in this image are " +str(label.count('car')))
# Out:
# Downloading yolov4.cfg from https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4.cfg
#   0% |                                                                        |
# Downloading yolov4.weights from https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
#  99% |####################################################################### |
# Downloading yolov3_classes.txt from https://github.com/arunponnusamy/object-detection-opencv/raw/master/yolov3.txt
# 100% |                                                                        |
# Number of cars in this image are 7
